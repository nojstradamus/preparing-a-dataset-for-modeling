# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] == 10,7

df = sns.load_dataset('mpg')
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df2 = df[['cylinders', 'displacement','horsepower', 'weight', 'acceleration']]
df2.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration
# 0          8         307.0       130.0    3504          12.0
# 1          8         350.0       165.0    3693          11.5
# 2          8         318.0       150.0    3436          11.0
# 3          8         304.0       150.0    3433          12.0
# 4          8         302.0       140.0    3449          10.5

# %%
df['horsepower'].isnull().sum()
# Out:
# 6

# %%
len(df)
# Out:
# 398

# %%
len(df2)
# Out:
# 398

# %%
len(df2.dropna())
# Out:
# 392

# %%
df2 = df2.dropna()

# %%
sns.pairplot(df2)

# %%
g = sns.PairGrid(df2, diag_sharey=False)
# Scatterplot.
g.map_upper(plt.scatter, alpha=.5)
# Fit line summarizing the linear relationship of the two variables.
g.map_lower(sns.regplot, scatter_kws=dict(alpha=0))
# Give information about the univariate distributions of the variables.
g.map_diag(sns.kdeplot, lw=3)
plt.show()

# %%
corrmat = df2.corr()
print(corrmat)

# Set up the matplotlib figure.
f, ax = plt.subplots(figsize=(12, 9))

# Draw the heatmap using seaborn.
sns.heatmap(corrmat, vmax=1, square=True)
plt.show()
# Out:
#               cylinders  displacement  horsepower    weight  acceleration
# cylinders      1.000000      0.950823    0.842983  0.897527     -0.504683
# displacement   0.950823      1.000000    0.897257  0.932994     -0.543800
# horsepower     0.842983      0.897257    1.000000  0.864538     -0.689196
# weight         0.897527      0.932994    0.864538  1.000000     -0.416839
# acceleration  -0.504683     -0.543800   -0.689196 -0.416839      1.000000

# %%
plt.scatter(x=df2['displacement'],y=df2['horsepower'])

# %%
plt.scatter(x=df2['displacement'],y=df2['weight'])

# %%
plt.scatter(x=df2['displacement'],y=df2['acceleration'])

# %%
plt.scatter(x=df2['horsepower'],y=df2['weight'])

# %%
plt.scatter(x=df2['horsepower'],y=df2['acceleration'])
